# %%
import pandas as pd
prisonpop = pd.read_csv('prisonpop.csv', index_col=0)
#http://www.bjs.gov/index.cfm?ty=nps
prisonpop = prisonpop.replace(',', '', regex=True)
prisonpop = prisonpop.replace('--','NaN', regex=True)
prisonpop = prisonpop.astype('float')

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
% matplotlib inline
natnlpop = prisonpop.iloc[:3]
statepop = prisonpop.iloc[3:]
natnlpop.T.plot(figsize=(12,8))

# %%
statepop.T.plot(figsize = (12,8), legend=None)

# %%
statepop[statepop>60000].dropna(axis=0, how='all')
# Out:
#             1978  1979  1980  1981  1982  1983  1984  1985  1986   1987  \
# California   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  66975
# Florida      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN
# New York     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN
# Texas        NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN
#
#              ...      2004    2005    2006    2007    2008    2009    2010  \
# California   ...    166556  170676  175512  174282  173670  171275  165062
# Florida      ...     85533   89768   92969   98219  102388  103915  104306
# New York     ...     63751   62743   63315   62620   60347     NaN     NaN
# Texas        ...    168105  169003  172116  171790  172506  171249  173649
#
#               2011    2012    2013
# California  149569  134534  135981
# Florida     103055  101930  103028
# New York       NaN     NaN     NaN
# Texas       172224  166372  168280
#
# [4 rows x 36 columns]

# %%
def square(x):
    return x*x
print square(9)
# Out:
# 81

# %%
str = 'the world is a big and beautiful place.'
print str.upper()
name = 'aleX sTorer'
print name.swapcase()
# Out:
# THE WORLD IS A BIG AND BEAUTIFUL PLACE.
# ALEx StORER

# %%
mystr = 'this is one cool looking string!'
if mystr.find('string')>len(mystr)/2:
    print 'string in 2nd half'
else:
    print 'string in 1st half'
# Out:
# string in 2nd half

# %%
str = 'daddy ran to help ann. up and down went the seesaw.'
for word in str.split():
    print word
# Out:
# daddy
# ran
# to
# help
# ann.
# up
# and
# down
# went
# the
# seesaw.

# %%
mylist = ['dogs',1,4,'fishes',['hearts','clovers'],list]
for element in mylist:
    print element
# Out:
# dogs
# 1
# 4
# fishes
# ['hearts', 'clovers']
# <type 'list'>

# %%
def strcount(string):
    return len(string)**2

# %%
strcount('hi')
# Out:
# 4

# %%
def numCaps(string):
    count = 0
    for i in string:
        if i.isupper():
            count += 1
    return count
numCaps(string)
# Out:
# 4

# %%
string = ['LoWer','ManHat']

# %%
# Out:
# Help on built-in function index:
#
# index(...)
#     L.index(value, [start, [stop]]) -> integer -- return first index of value.
#     Raises ValueError if the value is not present.

# %%
def findDog(string):
    stringlist = string.split()
    if 'dog' in stringlist:
        idx = stringlist.index('dog')
        return stringlist[:idx]
    else:
        return 'notfound'

findDog('the cat ran over the dog today')
# Out:
# ['the', 'cat', 'ran', 'over', 'the']

# %%
mydict = dict()
mydict['dogs'] = 14
mydict['fish'] = 10
mydict['dogs'] += 3
print mydict
# Out:
# {'fish': 10, 'dogs': 17}

# %%
mydict['fish']
# Out:
# 10

# %%
string = 'up and down went the Seesaw. Up it went. Down it went. Up, up, up!'

# %%
for i in [',','.','!']:
    string = string.replace(i, ' ')
print string
# Out:
# up and down went the Seesaw  Up it went  Down it went  Up  up  up

# %%
string = string.lower()
print string
# Out:
# up and down went the seesaw  up it went  down it went  up  up  up

# %%
words = string.lower().split()
d = dict.fromkeys(set(words), 0)

# %%
for word in words:
    d[word] += 1

# %%
print dict([(x, x**2) for x in range(0,11)])
# Out:
# {0: 0, 1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81, 10: 100}

# %%
import csv
f = open('blah.csv','w')
nums = [1,2,3]
c = csv.DictWriter(f, nums)
for i in range(0,10):
    d = dict()
# Out:
# <Text: Sense and Sensibility by Jane Austen 1811>

# %%
def uniqueLet(word):
    d = dict()
    for letter in word:
        if letter not in word:
            d[letter] = 1
        else:
            d[letter] +=1
    return d

# %%
def uniqueLet(word):
    d = dict()
    for letter in word:
        if letter in d:
            d[letter] += 1
        else:
            d[letter] = 1
    return d

# %%
print uniqueLet('letter')
# Out:
# {'r': 1, 'e': 2, 'l': 1, 't': 2}

# %%
def numletts(string):
    d = dict()
    string = string.split()
    for word in string:
# Out:
# 44764

# %%
len('word')
# Out:
# 4

# %%
float(text4.count('a'))/len(text4)
# Out:
# 0.014643016433938312

# %%
 saying = ['After', 'all', 'is', 'said', 'and', 'done','more', 'is', 'said', 'than', 'done']

# %%
tokens = set(saying)

# %%
tokens = sorted(tokens)

# %%
tokens[-2:]
# Out:
# ['said', 'than']

# %%
fdist1 = FreqDist(text1)

# %%
fdist1
# Out:
# FreqDist({u',': 18713, u'the': 13721, u'.': 6862, u'of': 6536, u'and': 6024, u'a': 4569, u'to': 4542, u';': 4072, u'in': 3916, u'that': 2982, ...})

# %%
vocabulary1 = fdist1.keys()

# %%
fdist1['whale']
# Out:
# 906

# %%
type(text1)
# Out:
# nltk.text.Text

# %%
text4.collocations()
# Out:
# United States; fellow citizens; four years; years ago; Federal
# Government; General Government; American people; Vice President; Old
# World; Almighty God; Fellow citizens; Chief Magistrate; Chief Justice;
# God bless; every citizen; Indian tribes; public debt; one another;
# foreign nations; political parties

# %%
len(set([word.lower() for word in text1 if word.isalpha()]))
# Out:
# 16948

# %%
nltk.corpus.gutenberg.fileids()
# Out:
# [u'austen-emma.txt',
#  u'austen-persuasion.txt',
#  u'austen-sense.txt',
#  u'bible-kjv.txt',
#  u'blake-poems.txt',
#  u'bryant-stories.txt',
#  u'burgess-busterbrown.txt',
#  u'carroll-alice.txt',
#  u'chesterton-ball.txt',
#  u'chesterton-brown.txt',
#  u'chesterton-thursday.txt',
#  u'edgeworth-parents.txt',
#  u'melville-moby_dick.txt',
#  u'milton-paradise.txt',
#  u'shakespeare-caesar.txt',
#  u'shakespeare-hamlet.txt',
#  u'shakespeare-macbeth.txt',
#  u'whitman-leaves.txt']

# %%
from nltk.corpus import brown

# %%
brown.categories()
# Out:
# [u'adventure',
#  u'belles_lettres',
#  u'editorial',
#  u'fiction',
#  u'government',
#  u'hobbies',
#  u'humor',
#  u'learned',
#  u'lore',
#  u'mystery',
#  u'news',
#  u'religion',
#  u'reviews',
#  u'romance',
#  u'science_fiction']

# %%
brown
# Out:
# <CategorizedTaggedCorpusReader in u'C:\\Users\\TimBo\\AppData\\Roaming\\nltk_data\\corpora\\brown'>

# %%
type(brown)
# Out:
# nltk.corpus.reader.tagged.CategorizedTaggedCorpusReader

# %%
cfd = nltk.ConditionalFreqDist(
    (genre, word)
    for genre in brown.categories()
    for word in brown.words(categories=genre))

# %%
genre_word =[(genre,word)
             for genre in ['news', 'romance']
             for word in brown.words(categories=genre)]
len(genre_word)
# Out:
# 170576

# %%
cfd = nltk.ConditionalFreqDist(genre_word)

# %%
cfd['news']
# Out:
# FreqDist({u'the': 5580, u',': 5188, u'.': 4030, u'of': 2849, u'and': 2146, u'to': 2116, u'a': 1993, u'in': 1893, u'for': 943, u'The': 806, ...})

# %%
cfd['romance']
# Out:
# FreqDist({u',': 3899, u'.': 3736, u'the': 2758, u'and': 1776, u'to': 1502, u'a': 1335, u'of': 1186, u'``': 1045, u"''": 1044, u'was': 993, ...})

# %%
cfd['romance']['could']
# Out:
# 193

# %%
days = ['Sunday', 'Monday','Tuesday','Wednesday','Thursday','Friday','Saturday']
cfd=nltk.ConditionalFreqDist(
    (genre, day)
    for genre in ['news', 'romance']
    for word in brown.words(categories=genre)
    for day in days)

# %%
list(cfd['romance'])
# Out:
# ['Monday', 'Tuesday', 'Friday', 'Wednesday', 'Thursday', 'Sunday', 'Saturday']

# %%
cfd.tabulate(conditions='Romance', samples = days, cumulative=True)
# Out:
#   Sunday Monday Tuesday Wednesday Thursday Friday Saturday
# R    0    0    0    0    0    0    0
# o    0    0    0    0    0    0    0
# m    0    0    0    0    0    0    0
# a    0    0    0    0    0    0    0
# n    0    0    0    0    0    0    0
# c    0    0    0    0    0    0    0
# e    0    0    0    0    0    0    0

# %%
from __future__ import division
import nltk, re, pprint
from bs4 import BeautifulSoup

# %%
sent = "i had a bad day. (applause) then he said."

# %%
re.sub(r'\([^)]*\)', '', sent)
# Out:
# 'i had a bad day.  then he said.'
